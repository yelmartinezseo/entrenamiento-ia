# %% [markdown]
# <a href="https://colab.research.google.com/github/yelmartinezseo/entrenamiento-ia/blob/main/Clustering_con_K_Means_en_Scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# Generamos datos sintéticos
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Visualizamos los datos generados
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
# Aplicamos K-Means
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# Obtenemos las coordenadas de los centros de los clusters
centers = kmeans.cluster_centers_

# Visualizamos los clusters y sus centros
plt.scatter(X[:,0], X[:,1], c=y_kmeans, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)
plt.show()
